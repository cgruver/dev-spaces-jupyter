# %% [markdown]
# # R Hello World Demo
#
# A simple notebook demonstrating R in Jupyter.

# %%
cat("Hello, World from R!\n")

# %%
# Create a simple data frame
df <- data.frame(
  Name = c("Alice", "Bob", "Charlie"),
  Score = c(95, 87, 92)
)
print(df)
cat("\nMean score:", mean(df$Score), "\n")
